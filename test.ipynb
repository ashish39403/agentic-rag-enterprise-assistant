# %%
# Out:
# Langfuse host: https://cloud.langfuse.com
# LLM base URL loaded: True

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 from langfuse import Langfuse
# ----> 3 langfuse = Langfuse(
#       4     public_key=os.environ["LANGFUSE_PUBLIC_KEY"],
#       5     secret_key=os.environ["LANGFUSE_SECRET_KEY"],
#       6     base_url=os.environ["LANGFUSE_BASE_URL"],
#       7 )
#       9 print("Auth:", langfuse.auth_check())
#
# TypeError: __init__() got an unexpected keyword argument 'base_url'
